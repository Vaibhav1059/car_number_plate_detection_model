# %%
from ultralytics import YOLO

# Load pretrained model (VERY IMPORTANT)
model = YOLO("yolov8n.pt")   # nano model (fast + good for beginners)

# Train model
model.train(
    data="../configs/data.yaml",
    epochs=30,
    imgsz=640,
    batch=8,
    name="plate_detector",
    project="../runs"
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.27 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.0  Python-3.10.20 torch-2.11.0+cpu CPU (11th Gen Intel Core i3-1115G4 @ 3.00GHz)
# ...
