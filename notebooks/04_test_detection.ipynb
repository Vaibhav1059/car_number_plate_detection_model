# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# Load your trained model
model = YOLO("../models/yolov8/best.pt")

# Image path
image_path = "../data/samples/test1.jpg"

# Run detection
results = model(image_path)

for box in results[0].boxes:
    conf = float(box.conf[0])
    coords = box.xyxy[0].tolist()

    print(f"Confidence: {conf:.2f}")
    print(f"Bounding Box: {coords}")

# Plot results
img = results[0].plot()

# Convert BGR → RGB
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.title("Detected Number Plate")
plt.axis("off")
# Out:
# image 1/1 d:\ml_project\anpr\notebooks\..\data\samples\test1.jpg: 640x640 1 license_plate, 151.1ms
# Speed: 31.6ms preprocess, 151.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Confidence: 0.93
# Bounding Box: [218.62754821777344, 702.8932495117188, 919.1785278320312, 852.08984375]
# (-0.5, 1199.5, 1199.5, -0.5)
